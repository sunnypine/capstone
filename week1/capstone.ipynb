# %%
from IPython.core.display import Image
import pandas as pd

# %% [markdown]
# # First look at data
#
# ### Below are two samples from New York City taxi data, March 2013

# %%
tripfare = pd.read_csv('./tripfare_sample.csv')
tripfare[:10]
# Out:
#    Unnamed: 0                         medallion  \
# 0           0  FE7B354FEB67B9C94BD34EA54469691C
# 1           1  B1370E6501ED61CEDA0160199AF7708C
# 2           2  CBC20164C22B96CAF5BC86C49F749DBB
# 3           3  B8256802A449BEF34E161654BFA8A2B6
# 4           4  0F9E0728AB1E40D5CEB0C6EDBF805CCB
# 5           5  D9F2D9B8520157F35D92FE58FF672D0D
# 6           6  CFC0F9CE3CA2B3A535EDADD92D54BE66
# 7           7  9EB16B34B8DCE740996F58F8187C9A34
# 8           8  BFB50E2A29509C8194B47AE5D1451C64
# 9           9  8AD0B4FDBF2F62F88E735AD08C3D2CD7
#
#                        hack_license  vendor_id      pickup_datetime  \
# 0  2C78614ADC9C602EC70D65CCB4E63B14        CMT  2013-03-01 00:00:04
# 1  08BF18740B38D64720C9E060429A3968        CMT  2013-03-01 00:00:18
# 2  F3310C8DA3DB753DDB5800F32D3CB8E3        CMT  2013-03-01 00:00:18
# 3  DF142C5256392C3CDA67C7DFFA5B88E2        CMT  2013-03-01 00:00:23
# 4  10D2E58D75E07D6B5AAFA329BF5A4CAC        CMT  2013-03-01 00:00:35
# ...

# %%
tripdata = pd.read_csv('./tripdata_sample.csv')
tripdata
# Out:
#    Unnamed: 0                         medallion  \
# 0           0  FE7B354FEB67B9C94BD34EA54469691C
# 1           1  B1370E6501ED61CEDA0160199AF7708C
# 2           2  CBC20164C22B96CAF5BC86C49F749DBB
# 3           3  B8256802A449BEF34E161654BFA8A2B6
# 4           4  0F9E0728AB1E40D5CEB0C6EDBF805CCB
# 5           5  D9F2D9B8520157F35D92FE58FF672D0D
# 6           6  CFC0F9CE3CA2B3A535EDADD92D54BE66
# 7           7  9EB16B34B8DCE740996F58F8187C9A34
# 8           8  BFB50E2A29509C8194B47AE5D1451C64
# 9           9  8AD0B4FDBF2F62F88E735AD08C3D2CD7
#
#                        hack_license  vendor_id   rate_code  \
# 0  2C78614ADC9C602EC70D65CCB4E63B14        CMT           1
# 1  08BF18740B38D64720C9E060429A3968        CMT           1
# 2  F3310C8DA3DB753DDB5800F32D3CB8E3        CMT           1
# 3  DF142C5256392C3CDA67C7DFFA5B88E2        CMT           1
# 4  10D2E58D75E07D6B5AAFA329BF5A4CAC        CMT           1
# 5  A38CE69F84E515A71DF18F9786F13690        CMT           1
# ...

# %% [markdown]
# # What can this data tell us?

# %%
Image('png/pickup_20k_1.png',width=1000, height=1000)

# %%
Image('png/dropoff_20k_1.png',width=800, height=800)

# %% [markdown]
# # Plan
#
# ### Taxi trips from manhatten to airports
# ### Time/speed variation in one day / one week / holidays
# ### Goal: Website provides information of trip time at any time of year
